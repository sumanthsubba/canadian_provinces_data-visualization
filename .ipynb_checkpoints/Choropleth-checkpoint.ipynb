# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import geopandas as gpd
import fiona
import plotly.graph_objects as go

# %%
import sys
'geopandas' in sys.modules
# Out:
# True

# %%
#set the filepath and load in a shapefile

url = "datasets/geo-data/gpr_000b11a_e.shp"
map_df = gpd.read_file(url)

# %%
pwd
# Out:
# 'C:\\Users\\SubbaramanS\\Data Science'

# %%
type(map_df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
map_df.head()
# Out:
#   PRUID                                        PRNAME               PRENAME  \
# 0    59       British Columbia / Colombie-Britannique      British Columbia
# 1    24                               Quebec / Québec                Quebec
# 2    62                                       Nunavut               Nunavut
# 3    11  Prince Edward Island / Île-du-Prince-Édouard  Prince Edward Island
# 4    47                                  Saskatchewan          Saskatchewan
#
#                  PRFNAME PREABBR   PRFABBR  \
# 0   Colombie-Britannique    B.C.     C.-B.
# 1                 Québec    Que.        Qc
# 2                Nunavut    Nvt.        Nt
# 3  Île-du-Prince-Édouard  P.E.I.  Î.-P.-É.
# 4           Saskatchewan   Sask.     Sask.
#
#                                             geometry
# 0  MULTIPOLYGON (((-123.53977 48.31735, -123.5397...
# 1  MULTIPOLYGON (((-74.63814 44.99984, -74.63859 ...
# 2  MULTIPOLYGON (((-79.99352 51.27725, -79.99475 ...
# ...

# %%
map_df.plot()

# %%
df = pd.read_csv("datasets/abtme.csv", header = 0)
df
# Out:
#     Count  Region
# 0    4018      35
# 1     598      48
# 2     230      59
# 3     577      46
# 4     205      13
# 5       0      10
# 6     209      12
# 7       0      61
# 8       0      62
# 9     186      11
# 10    784      24
# 11    792      47
# 12      1      60

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df[['Count', 'Region']]
score = df.rename(index=str, columns={"Region": "PRUID",
                                      "Count": "num_of_users"})
score
# Out:
#     num_of_users                    PRENAME
# 0           4018                   Ontario
# 1            598                    Alberta
# 2            230          British Columbia
# 3            577                  Manitoba
# 4            205              New Brunswick
# 5              0  Newfoundland and Labrador
# 6            209                Nova Scotia
# 7              0      Northwest Territories
# 8              0                    Nunavut
# 9            186       Prince Edward Island
# 10           784                     Quebec
# 11           792               Saskatchewan
# 12             1                      Yukon

# %%
map_df
# Out:
#    PRUID                                             PRNAME  \
# 0     59            British Columbia / Colombie-Britannique
# 1     24                                    Quebec / Québec
# 2     62                                            Nunavut
# 3     11       Prince Edward Island / Île-du-Prince-Édouard
# 4     47                                       Saskatchewan
# 5     60                                              Yukon
# 6     46                                           Manitoba
# 7     35                                            Ontario
# 8     13                  New Brunswick / Nouveau-Brunswick
# 9     61  Northwest Territories / Territoires du Nord-Ouest
# 10    48                                            Alberta
# 11    10  Newfoundland and Labrador / Terre-Neuve-et-Lab...
# 12    12                      Nova Scotia / Nouvelle-Écosse
#
#                       PRENAME                    PRFNAME PREABBR   PRFABBR  \
# ...

# %%
merged = map_df.set_index('PRENAME').join(score.set_index('PRENAME'))
merged
# Out:
#                           PRUID  \
# PRENAME
# British Columbia             59
# Quebec                       24
# Nunavut                      62
# Prince Edward Island         11
# Saskatchewan                 47
# Yukon                        60
# Manitoba                     46
# Ontario                      35
# New Brunswick                13
# Northwest Territories        61
# Alberta                      48
# Newfoundland and Labrador    10
# Nova Scotia                  12
#
#                                                                       PRNAME  \
# PRENAME
# British Columbia                     British Columbia / Colombie-Britannique
# Quebec                                                       Quebec / Québec
# Nunavut                                                              Nunavut
# Prince Edward Island            Prince Edward Island / Île-du-Prince-Édouard
# Saskatchewan                                                    Saskatchewan
# ...
