# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import geopandas as gpd
import fiona
import plotly.graph_objects as go
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
abtmene = [193, 25, 22, 58, 9, 0, 4, 0, 0, 4, 18, 28, 0]
abtme = [4018, 598, 230, 577, 205, 0, 209, 0, 0, 186, 784, 792, 1]
index = ['ON', 'AB', 'BC', 'MB', 'NB', 
         'NL', 'NS', 'NT', 
         'NU', 'PEI', 'QC', 'SK', 'YK']
df = pd.DataFrame({'About Me Filled': abtmene,
                   'About Me not Filled': abtme}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
ax = df.plot.bar(title = "Number of Users who have filled out 'About Me'", y='About Me Filled', rot=0, figsize=(20, 10))

# %%
ax2 = df.plot.bar(title = "Number of Users who haven't filled out 'About Me'", y='About Me not Filled', rot=0, figsize=(20, 10))

# %%
fig = ax.get_figure()
fig.savefig('abtmene')

# %%
fig2 = ax2.get_figure()
fig2.savefig('abtme')
